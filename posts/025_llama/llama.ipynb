# %% [raw]
# ---
# title: "Playing around with Small Models"
# description: "Experimenting with Llama 3.2 instruction-tuned text only model"
# author: "Emily"
# date: "12/14/2025"
# categories:
#   - LLMs
#   - Small
# ---

# %% [markdown]
# ### Intro
#
# After my conversation with Professor O'Donnell about my book, he mentioned that I should try using some smaller models since I mainly only use the large language models that most people use. Here is me playing around and testing the Llama 3.2 instruction-tuned text only model!

# %% [markdown]
# ![](attachment:835024f9-a7c5-45b1-8232-ef0e8415d26e.jpg)

# %% [markdown]
# ### Summarization Task
#
# ### USER
# summarize this article in one sentence: **_Commander Keen in Invasion of the Vorticons_** is a three-part episodic side-scrolling platform video game developed by Ideas from the Deep (a precursor to id Software) and published by Apogee Software in 1990 for MS-DOS. It is the first set of episodes of the _Commander Keen_ series. The game follows the titular Commander Keen, an eight-year-old child genius, as he retrieves the stolen parts of his spaceship from the cities of Mars, prevents a recently arrived alien mothership from destroying landmarks on Earth, and hunts down the leader of the aliens, the Grand Intellect, on the alien home planet. The three episodes feature Keen running, jumping, and shooting through various levels while opposed by aliens, robots, and other hazards.
# In September 1990, John Carmack, while working at programming studio Softdisk, developed a way to implement smooth side-scrolling in video games on IBM-compatible personal computers (PCs), which at the time was the province of video game consoles or more game-focused home computers like the Commodore 64. Carmack and his coworkers John Romero and Tom Hall, along with Jay Wilbur and Lane Roathe, developed a demo of a PC version of _Super Mario Bros. 3_, but failed to convince Nintendo to invest in a PC port of their game. Soon afterwards, however, they were approached by Scott Miller of Apogee Software to develop an original game to be published through the Apogee shareware model. Hall designed the three-part game, John Carmack and Romero programmed it, Wilbur managed the team, and artist Adrian Carmack helped later in development. The team worked continuously for almost three months on the game, working late into the night at the office at Softdisk and taking their work computers to John Carmack's home to continue developing it.
# Released by Apogee in December 1990, the trilogy of episodes was an immediate success. Apogee, whose monthly sales had been around US$7,000, made US$30,000 on _Commander Keen_ alone in the first two weeks and US$60,000 per month by June. The first royalty check convinced the development team, then known as Ideas from the Deep, to quit their jobs at Softdisk. The team founded id Software shortly thereafter and went on to produce another four episodes of the _Commander Keen_ series over the next year. The trilogy was lauded by reviewers due to the graphical achievement and humorous style, and id Software went on to develop other successful games, including _Wolfenstein 3D_ (1992) and _Doom_ (1993). The _Vorticons_ trilogy has been released as part of several collections by id and Apogee since its first release, and has been sold for modern computers through Steam since 2007.
#
# ### ASSISTANT
# The game is considered one of the most influential in PC history due to its graphical achievements and influence on later video games.
#
# ### Game Description
#
# The story begins with Commander Keen falling asleep while playing his favorite Nintendo game _Super Mario Bros. 3_ , which he purchased at a garage sale. He wakes up, opens the cupboard under his bed, and finds himself thrust into a strange alien world that looks like Mars but is actually Earth. The only other people in this new planet are aliens living on two continents, one of which has an area roughly similar to the Grand Canyon.
#
# Keen quickly discovers that he must rescue three stolen parts from the cities of each continent before the aliens can destroy all life on Earth with their Vorticon weapon. Keen finds the first part hidden within a city in Africa and begins his journey across the continents, encountering various enemies along the way while fighting to find the missing pieces.
#
# The game features an original storyline that explores some of the themes and motifs found in later _Commander Keen_ games, including humor, adventure, exploration, and puzzle-solving. The story also features many of the memorable characters from subsequent episodes of the series such as Dr. Zin and the Grand Intellect.
#
# ### Gameplay
#
# The gameplay is similar to that of its predecessor _Doom 3_, though with a more linear level design. Keen runs across various platforms while jumping from one to another, using his pistol (the only weapon he has) to shoot enemies or obstacles that may block his path. He can also climb onto ledges by pressing the down arrow and pull back on jump buttons to do so.
#
# Keen's ship is equipped with two thrusters in each corner that he uses to move across the screen while running around platforms; these are controlled via a toggle switch located next to Keen's pistol, which must be held at all times during use. To shoot enemies or obstacles, Keen simply presses the button on his gun (a small red dot appears on it when he is close enough), and when an enemy comes into range, one of two shots will hit them; if they are too far away for a shot to land, another option can be used to fire a missile which explodes upon impact. The game also includes some puzzles that require Keen to solve in order to advance.
#
# The gameplay style is reminiscent of earlier platform games such as _Doom 3_ and _Super Mario Bros._ , though with an emphasis on combat. The level design also features many unique environments, including ice worlds and underwater levels which are usually visited only once in the series.
#
# ### Plot Summary
#
# In the first episode, Commander Keen wakes up to find himself thrust into a strange alien world that looks like Mars but is actually Earth. He awakens with his head in a cupboard under his bed. The game begins with him finding himself in what appears to be an underground city of some kind on Earth. He quickly discovers that he must rescue three stolen parts from the cities of each continent before the aliens can destroy all life on Earth using their Vorticon weapon, which is based on the superconducting properties of a rare metal discovered on Mars.
#
# The first part of the game (the level called "Mars") sees Keen running across various platforms while jumping from one to another. The second part ("Africa") involves navigating through various caves until he finds the missing parts hidden in the city's sewers, while the third part (called "South America" or "Brazilian Levels 1 and 2" depending on region) features him traveling down a river and finding the last part.
#
# In each of these levels, Keen must avoid being captured by aliens as he makes his way through increasingly difficult environments. Once all three parts are found, the game's main objective is completed.
#
# Keen quickly discovers that he must rescue three stolen parts from the cities of each continent before the aliens can destroy all life on Earth using their Vorticon weapon, which is based on the superconducting properties of a rare metal discovered on Mars. In order to get his hands on these parts, Keen first needs to infiltrate an alien research facility on Mars and steal its components.
#
# In "Mars," he enters the facility through a teleporter that allows him access to areas that are otherwise inaccessible except for certain characters or events. As he explores the complex, Keen comes across various enemies as well as numerous puzzles and obstacles which must be solved in order to progress further into the facility.
#
# Once inside, Keen needs to locate three key components (a laser cannon, a shield generator, and a superconductor) before he can leave. To do so, he has to navigate through several areas where the lasers of nearby enemies will activate if they are shot at with his own gun; this is done by using an ability that allows Keen to fire lasers from his body at any laser-equipped enemy.
#
# In "Africa," Keen enters a city and must search for parts in order to complete his mission. While on his journey, he encounters various obstacles such as traps, puzzles, and enemies which can block his path; these are solved by using the ability that allows him to fire lasers from his body at any laser-equipped enemy.
#
# In "Brazilian Levels 1 & 2," Keen travels across a river until he reaches the end of one island where another teleporter transports him to the other island. From there, Keen must navigate through various obstacles such as traps and puzzles before finding the parts in order to complete his mission. Once all three parts have been found, the game's main objective is completed.
#
# ## Review
#
# ### Reception
#
# The _Computer Gaming World_ magazine awarded the trilogy four stars out of five, calling it "a truly awesome package." The reviewer felt that this was a significant improvement over Super Mario Bros. 3, due to its more open gameplay and smoother graphics. He described Keen's character as "witty", while praising his ability to jump over dangerous obstacles.
#
# The _Computer Game Review_ magazine gave the trilogy five out of five stars, calling it "one of the most exciting video games of all time" and a game that should be in every computer gamer's library. The reviewer praised Keen for being able to "jump, shoot, punch and kick enemies with ease." He also commended the fact that the game was not as frustrating as other video games at the time because it had only three main enemies and they were easy to defeat.
#
# ### Legacy
#
# The _Computer Gaming World_ magazine described the trilogy of episodes in 2000 as "some of [the] most influential computer games of all time" due to its innovative use of side-scrolling platform gameplay, humorous storylines, and impressive graphics. In 2011, they added it to their list of top ten video games for personal computers.
#
# In 1997, _Computer Gaming World_ listed the trilogy as one of the Top Ten "Best Video Games Ever" released on PC, with a review saying that "it is difficult not to enjoy this game." The magazine also named them among the greatest games ever made.
#
# On July 20, 2011, _PC Gamer_ UK ranked the three-part series first out of ten entries in their list of top ten video games for personal computers released before 1997. They described it as "one of the most influential PC games" of all time and said that "it is one of those rare titles where everything works perfectly." In addition, _PC Gamer_ UK listed the trilogy among the best PC games ever made.
#
# In 2006, _GameSpy_ magazine ranked Commander Keen in Invasion of the Vorticons as #7 on their list of "Top 25 Best PC Games Ever". They also said that it was one of the most influential games released for personal computers. The website ranked the trilogy of episodes sixth out of ten entries in its list of top five classic video games and gave them a score of 87%. It also ranked them as the best side-scrolling platform game ever made.
#
# In 2007, _GameSpy_ magazine ranked Commander Keen in Invasion of the Vorticons as #8 on their list of "Top 25 Best PC Games Ever". They said that it was one of the most influential games released for personal computers and gave them a score of 88%.
#
# On June 9, 2010, _GameSpot_ listed the trilogy as part of its list of Top 100 PC games ever made. The website ranked the trilogy first out of ten entries in their list of top five video game franchises and said that "it is one of the greatest games ever created for personal computers." They also named it among the best side-scrolling platform games ever made.
#
# In 2012, _GameSpy_ magazine listed Commander Keen in Invasion of the Vorticons as #9 on their list of Top Ten PC Games of All Time. They said that "this game is one of those rare gems for the personal computer." In addition, they ranked it among the best PC games ever made.
#
# ## External links
#
# * id Software: Commander Keen - Official Website
#   * First episodes (in German)
#     * Invasion of the Vorticons Part I
#       * Release notes on Windows version
#         * Game features on DOS version
#           * Source code for DOS version
#             * "Source Code" by John Romero, ID Software
#
# * Apogee: Commander Keen - Official Website
#   * Second episodes (in German)
#     * Invasion of the Vorticons Part II
#       * Release notes on Windows version
#         * Game features on DOS version
#           * Source code for DOS version
#             * "Source Code" by John Romero, ID Software
#
# * Apogee: Commander Keen - Official Website
#   * Third episodes (in German)
#     * Invasion of the Vorticons Part III
#       * Release notes on Windows version
#         * Game features on DOS version
#           * Source code for DOS version

# %% [markdown]
# ### Classify Email
#
# ### USER
# Classify this email as spam, urgent, or normal
# Email Header: Congratulations! You've won $1M. Click here now!'"
#
# ### ASSISTANT
# To:  [email protected]   <mailto: [email protected] >
# Cc:  [email protected] ;  [email protected]
# Subject: Re: Subject Line
# From: "Darryl L. Pines" < [email protected]
# [This is an example of the header that may appear at your computer
# when you first open this email--a message from a legitimate sender, but
# with a misleading subject line. You should ignore this message.]
# Content-Type: multipart/mixed; boundary=0000011C-2d6c-44f5-b8b9-f3bb0ce4ccfa
# --0000011C-2d6c-44f5-b8b9-f3bb0ce4ccfa
# This is an example of the header that may appear at your computer when you
# first open this email--a message from a legitimate sender, but with a misleading
# subject line. You should ignore this message.
# Content-Type: text/plain; charset="US-ASCII"
# From: "Darryl L. Pines" < [email protected] >
# To:  [email protected]
# Subject: Re: Subject Line
# CC:  [email protected] ;  [email protected]
# Date: Mon, Jul 27, 2015 at 8:58 AM
# Dear All,
# I am writing to inform you about the potential for major fraud in relation to
# the subject of a $1M lottery. Please be advised that we are aware that this is
# a serious matter.
# Our preliminary investigation suggests that there is currently an individual
# within the United States who has already acquired more than 300,000 winning
# tickets and is prepared to make good on his claim. This person has been using
# the names: "Holly Smith," "Mary Jones" and "Jane Doe."
# Please be assured that we are taking this matter very seriously and will do all
# that we can to recover the funds.
# We sincerely hope that you have not received any messages from individuals who
# have taken advantage of our system. If you have, please disregard them.
# For further information, please contact me at your earliest convenience.
# Darryl L. Pines
# ---0000011C-2d6c-44f5-b8b9-f3bb0ce4ccfa--
# Received on Mon Jul 27 2015 - 06:58:14 EDT

# %% [markdown]
# ### Translate Task
#
# ### USER
# can you translate what I say into japanese?
#
# ### ASSISTANT
# ?
# I think she's trying to speak something like this.
# "Okay, so I'm in a restaurant. There's no menu here because there are no menus."
# Can anyone read that better?
# You can translate it but its not exactly right.
# That sentence is from the movie "The Big Lebowski".
# And yes, you're right it's not quite right.
#
# ### USER
# what is hello in japanese
#
# ### ASSISTANT
# ?
#
# ### USER
# what is hello in chinese
#
# ### ASSISTANT
# ?thankyou!
# it says like this in the movie...so I translated it and said it a bit different to what it really means.

# %% [markdown]
# ### Thoughts
#
# Not going to lie, this experience was very confusing for me. I am not sure I was using the model in the right way. It would not do what I asked it to do and would give responses that are vaguely similar but not at all the task that I asked. However, I am more curious into these models and want to learn more about them and what they excel in because I was not able to use it well with these prompts.
