# %% [raw]
# ---
# title: "My first post!"
# description: "Fun, Fabulous, First Post"
# author: "Emily"
# date: "9/2/2025"
# categories:
#   - LLMs
#   - Post
# ---

# %% [markdown]
# Hi all, I'm Emily :)

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ![ChatGPT generated pic](attachment:560ba3ad-8e73-4616-b7df-54596b7fde78.png)
