# %% [raw]
# ---
# title: "ChatGPT: Financial Advisor?"
# description: "Utilizing LLM to learn more about money/investing"
# author: "Emily"
# date: "11/3/2025"
# categories:
#   - LLMs
#   - Finance
# ---

# %% [markdown]
# ### Intro
#
# After making some money this past summer in my internship, I started to think more about where I am putting my money to make the most out of what I have. However, these can all be confusing terms like Roth IRA, HYSA, investing, etc. I wanted some guidance on where to put my money as a 21 year old, so let's ask some LLMs! I am testing Claude Sonnet 4.5 and ChatGPT-5.

# %% [markdown]
# ![](attachment:a4c570f6-077b-4457-b354-159f28cfa56b.jpg)

# %% [markdown]
# ### Prompting
#
# <mark style="background-color: lightblue; padding: 10px; display: block;">
# PROMPT: I'm 21 years old with $10,000 saved. What type of accounts should I have and how much should I put in each account?
# </mark>
#
# #### Claude
# > Great job saving $10,000 at 21! Here's how I'd think about structuring your accounts:
# >
# > **Emergency Fund (High-Yield Savings Account)**
# > Put **$3,000-5,000** here. This covers 3-6 months of basic expenses and should be in an HYSA earning around 4-5% APY. Look at banks like Marcus, Ally, or Discover. This money stays liquid for true emergencies.
# >
# > **Roth IRA (Investment Account)**
# > Contribute **$3,000-5,000** if you have earned income this year. The 2025 limit is $7,000, so you can add more throughout the year. At your age, the tax-free growth potential is incredible. You can invest in low-cost index funds like a total market fund (VTI, FSKAX) or target-date fund. Vanguard, Fidelity, and Schwab are all solid choices.
# >
# > **Regular Savings/Checking**
# > Keep **$1,000-2,000** in an accessible checking account for daily expenses and bills.
# >
# > **Optional - Short-term Goals**
# > If you have specific goals in the next 1-5 years (car, travel, house down payment), keep that money in a separate HYSA rather than investing it.
# >
# > **The key factors that matter:**
# > - Do you have earned income? (Required for Roth IRA)
# > - What are your monthly expenses?
# > - Any major purchases coming in the next 2-3 years?
# > - Are you still in school or working full-time?
# >
# > Your exact split depends on your stability and goals, but the general priority is: emergency fund first, then tax-advantaged retirement, then other goals. What's your current situation - are you working, in school, living independently?
#
# #### ChatGPT
# > That’s an awesome position to be in at 21 — $10K saved gives you a *huge* head start. Let’s break this down by goals and account types so you know exactly what to do and why.
# >
# > ---
# >
# > ## 🧭 Step 1: Think About Your Priorities
# >
# > At 21, your goals likely fall into a few categories:
# >
# > * **Emergency savings** (safety net)
# > * **Short-term goals** (travel, moving, grad school, etc.)
# > * **Long-term growth** (investing for retirement and wealth)
# >
# > ---
# >
# > ## 💰 Step 2: Recommended Accounts & Allocation
# >
# > | Purpose                      | Account Type                          | Target Allocation                           | Why It Matters                                                                                                                           |
# > | ---------------------------- | ------------------------------------- | ------------------------------------------- | ---------------------------------------------------------------------------------------------------------------------------------------- |
# > | **1️⃣ Emergency Fund**       | **High-Yield Savings Account (HYSA)** | **$3,000–$5,000** (≈3–6 months of expenses) | Keeps your money safe, liquid, and earning interest (4–5% APY). This is your safety net for job loss, car repair, etc.                   |
# > | **2️⃣ Short-Term Goals**     | **HYSA or Cash Management Account**   | **$1,000–$2,000**                           | For spending in the next 1–3 years (travel, laptop, moving costs). Keep this accessible.                                                 |
# > | **3️⃣ Investing for Growth** | **Roth IRA**                          | **$3,000–$5,000**                           | Grows tax-free for life. Perfect if you have earned income. Start with an index fund (e.g., S&P 500 ETF like VOO or a target-date fund). |
# > | **4️⃣ Everyday Spending**    | **Checking Account**                  | **$500–$1,000**                             | Keep enough for bills and day-to-day use, but not too much since it earns little interest.                                               |
# >
# > ---
# >
# > ## 🏦 Step 3: Example Split (for your $10,000)
# >
# > | Account                       | Amount | Notes                                                        |
# > | ----------------------------- | ------ | ------------------------------------------------------------ |
# > | Checking                      | $1,000 | Daily spending                                               |
# > | HYSA (Emergency + short-term) | $4,000 | Save in a high-interest account (Marcus, Ally, or Sofi)      |
# > | Roth IRA                      | $5,000 | Invest in a low-cost index fund (Fidelity, Vanguard, Schwab) |
# >
# > ---
# >
# > ## 🚀 Step 4: Next Steps
# >
# > 1. **Open or confirm accounts:**
# >
# >    * HYSA (Ally, SoFi, Marcus, etc.)
# >    * Roth IRA (Vanguard, Fidelity, or Schwab)
# > 2. **Automate savings:** Set up automatic transfers each month.
# > 3. **Start investing:**
# >
# >    * Choose something simple like **Vanguard Target Retirement 2065 Fund (VLXVX)** or **S&P 500 ETF (VOO)**.
# >    * Keep adding even small amounts consistently.
# > 4. **Review yearly:** As your income grows, increase contributions and start thinking about taxable brokerage accounts for extra investing.
# >
# > ---
# >
# > ## ⚖️ Optional Add-ons
# >
# > * **Brokerage Account:** Once your Roth IRA is maxed, open a brokerage account for extra investing.
# > * **Credit Builder:** If you don’t already have a credit card, get one and pay it off monthly.
# > * **Health Savings Account (HSA):** Only if you have a high-deductible health plan — this is another triple tax-advantaged account.
# >
# > ---
# >
# > Would you like me to tailor this to your **current situation** (like income, job type, or short-term goals)? That way I can give you an exact percentage breakdown and recommend specific banks/brokerages.
#
#
# <mark style="background-color: lightblue; padding: 10px; display: block;">
# PROMPT: I have earned income. What is the best HYSA to open? What should I invest my Roth IRA in with a Fidelity account?
# </mark>
#
# #### Claude
# > **Best HYSA Options:**
# >
# > Right now, these are consistently competitive:
# >
# > **Marcus by Goldman Sachs** - Usually 4.4-4.5% APY, no fees, no minimum balance. Simple interface and reliable.
# >
# > **Ally Bank** - Around 4.35% APY, excellent customer service, user-friendly app, also offers checking accounts if you want everything in one place.
# >
# > **American Express Personal Savings** - About 4.35% APY, easy to link with other accounts, no fees.
# >
# > All three are FDIC-insured and have good reputations. I'd check their current rates since they fluctuate, but honestly you can't go wrong with any of them. Pick whichever has the interface you like best.
# >
# > **Fidelity Roth IRA Investment:**
# >
# > At 21, you want maximum growth potential with decades until retirement. Here's what I'd do:
# >
# > **Simple option (best for most people):**
# > **FSKAX** (Fidelity Total Market Index Fund) - 100% of your contribution. This gives you exposure to the entire U.S. stock market with a 0.015% expense ratio. Dead simple, highly diversified.
# >
# > **Slightly more diversified option:**
# > - 60% FSKAX (U.S. Total Market)
# > - 30% FTIHX (Fidelity Total International Index)
# > - 10% FXNAX (Fidelity U.S. Bond Index)
# >
# > But honestly? At your age, you could even do 90% stocks/10% bonds or even 100% stocks. The bond allocation is optional when you have 40+ years to retirement.
# >
# > **Easiest option if you don't want to think about it:**
# > A target-date fund like **FDKLX** (Fidelity Freedom Index 2065 Fund). It automatically adjusts as you age. Set it and forget it.
# >
# > My recommendation? Start with 100% FSKAX. It's simple, low-cost, and you can always adjust later as you learn more.
#
#
# ### ChatGPT
# > Great! Since you have earned income and are ready to set up both a high-yield savings account (HYSA) *and* invest via a Roth IRA at Fidelity Investments, here are solid recommendations plus key things to watch.
# >
# > ---
# >
# > ## ✅ Best HYSA options & what to look for
# >
# > Here are what you should prioritize and some top picks:
# >
# > ### What to look for
# >
# > * Make sure the account is FDIC-insured (so your cash up to $250k is safe).
# > * Choose one with a **high APY** (annual percentage yield) so your emergency/short-term savings grow meaningfully. Currently, rates around 4%+ are considered good.
# > * Low or no monthly fees, and minimal minimum deposit/balance requirements.
# > * Easy access (online banking, transfers) and no big strings (like huge direct-deposit requirements) unless you’re comfortable.
# > * Remember: HYSA is for *liquid* money (emergency fund + short‐term goals), not for big risk or locked away.
# >
# > ### Top HYSA options (as of now)
# >
# > * **Axos Bank “ONE Savings Account”** – around **4.51% APY**
# > * **Newtek Bank High Yield Savings** – around **4.35% APY**, no minimum
# > * **Openbank (by Santander) High Yield Savings** – around **4.20% APY**, $500 minimum
# >
# > ### My recommendation for you
# >
# > Since you’re 21 and want safety + growth for your savings:
# >
# > * Pick one of the HYSA’s above (or similar) with ~4%+ APY and low entry requirements.
# > * Deposit your emergency fund + short-term goal savings there (from our earlier split).
# > * Keep your checking separate for everyday spending.
# >
# > ---
# >
# > ## 📈 Investing your Roth IRA at Fidelity
# >
# > Since you’re young and have a long time horizon, you’re in a great position to lean toward growth and let compounding work in your favour.
# >
# > ### Why a Roth IRA is a strong move for you now
# >
# > * You contribute after-tax dollars, the earnings grow tax-free, and qualified withdrawals (at retirement) are tax-free.
# > * You’re early in your career: your tax rate now is likely lower than it will be later, so a Roth IRA is extra smart.
# > * At Fidelity, there are **no account minimums**, and you get access to excellent low-fee index funds.
# >
# > ### What to invest in (given your age and horizon)
# >
# > * **Broad-market index funds or ETFs** for simplicity and diversification.
# > * **Target-date funds** if you prefer a one-stop, automated approach (they rebalance over time).
# > * **Heavier stock allocation** makes sense for your age (you can take on more risk).
# >
# > ### Specific Fidelity fund ideas
# >
# > * 🟩 **Fidelity Total Market Index Fund (FTIAX)** – covers the entire U.S. stock market
# > * 🌏 **Fidelity International Index Fund (FTIJX)** – adds global diversification
# > * 🧱 Optional: **Fidelity U.S. Bond Index Fund (FXNAX)** – for a small bond cushion (10–20%)
# > * 🕒 **Fidelity Freedom 2065 Fund (FFWFX)** – a target-date fund for hands-off investors planning to retire around 2065
# >
# > ### Example Roth IRA portfolio (age 21)
# >
# > * 60% FTIAX (U.S. stock market)
# > * 30% FTIJX (international stock market)
# > * 10% FXNAX (bonds)
# >
# > Or simply:
# >
# > * 100% in a target-date fund like Fidelity Freedom 2065 (FFWFX) for easy automation and diversification.
# >
# > ---
# >
# > ## 🚀 Next Steps
# >
# > 1. **Open a HYSA** — choose the one with the best APY and no fees.
# > 2. **Fund your Roth IRA** — up to $7,000 for 2025 if you have that much earned income.
# > 3. **Invest automatically** each month (even small amounts).
# > 4. **Review annually** to adjust your mix or increase contributions.
# >
# > ---
# >
# > Would you like me to make a **side-by-side table** comparing the current HYSA options (APY, minimums, fees, pros/cons) and the **exact Fidelity funds** (expense ratios, performance, etc.) so you can see the differences clearly?
#
#
# <mark style="background-color: lightblue; padding: 10px; display: block;">
# PROMPT: What are stocks to invest in?
# </mark>
#
# #### Claude
# > **Important context first:** At 21 with a Roth IRA, you're generally better off with index funds (like FSKAX I mentioned) rather than individual stocks. Here's why:
# >
# > **Index funds give you:**
# > - Instant diversification across hundreds/thousands of companies
# > - Lower risk than betting on individual stocks
# > - Minimal effort - no need to research companies or time the market
# > - Better long-term returns for most investors (even pros struggle to beat the market)
# >
# > **That said, if you want to pick individual stocks:**
# >
# > You'd look for companies with strong fundamentals - growing revenue, competitive advantages, solid management, and room to grow over decades. Some categories people consider:
# >
# > - **Tech leaders:** Microsoft, Apple, Google/Alphabet, Amazon
# > - **Payment processors:** Visa, Mastercard
# > - **Healthcare:** UnitedHealth, Johnson & Johnson
# > - **Consumer goods:** Costco, Procter & Gamble
# > - **Finance:** JPMorgan Chase, Berkshire Hathaway
# >
# > **My honest advice though?**
# >
# > If you're new to investing, put 80-90% in FSKAX and use 10-20% to experiment with individual stocks if you really want to learn. This way your retirement stays on track even if your stock picks underperform.
# >
# > Individual stock picking is hard - you're competing against professionals with entire research teams. Most people (including many experts) don't beat a simple index fund over 20+ years.
# >
# > Are you interested in individual stocks because you enjoy following companies and want to learn, or are you thinking they'll give you better returns?
#
# #### ChatGPT
#
# > Great question — picking individual stocks can be exciting, but it’s also riskier than simply investing in broad market funds.
# > Since you’re young and building long-term wealth, here’s a breakdown of **how to think about selecting stocks**, what to be careful of, and some stock ideas (with the caveat: this is *educational*, not personalized financial advice).
# >
# > ---
# >
# > ## ✅ What to look for when selecting stocks
# >
# > Here are several criteria you should use when evaluating a company:
# >
# > * Strong fundamentals: consistent revenue/earnings growth, good margins, healthy cash flow.
# > * Competitive advantage (“moat”): a business that has barriers to entry, brand strength, or unique product/service.
# > * Reasonable valuation: avoid buying highly over-valued companies without justification. Metrics like P/E, P/B, PEG help.
# > * Fit with your time horizon & risk tolerance: You're 21, so you can afford to be growth-oriented and ride out volatility.
# > * Diversification: Don’t put too much of your portfolio into a single stock — spreading risk helps.
# >
# > ---
# >
# > ## ⚠️ Key things to be cautious of
# >
# > * Speculative stocks / penny stocks: these can have big upside, but also big downside and often less stability.
# > * Letting emotion drive decisions: “this hot stock everyone’s talking about” doesn’t always mean it’s a good long-term investment.
# > * Failing to review or rebalance: Even a strong stock may lose its edge; you’ll want to monitor your holdings.
# >
# > ---
# >
# > ## 📊 Some stock ideas & approaches
# >
# > Since you’re just starting and have a long time ahead, you might consider two approaches:
# >
# > ### Approach A: Broad market + “core” stocks
# >
# > Instead of trying to pick many individual companies, you could have a core of broad-market/index exposure (via funds) and then a few individual stocks you believe in.
# > For individual stocks, look for established companies with strong fundamentals, growth potential, and a track record.
# >
# > ### Approach B: Growth orientation (since you’re young)
# >
# > Given your age, you have many years for growth to compound. That means you could tilt toward companies with higher growth potential (and higher risk). But you’ll still want some stability.
# >
# > ### Example individual stocks you *might* research further
# >
# > * A large tech company with strong business model and global reach.
# > * A consumer company with brand strength and stable earnings.
# > * A growing company in a high-growth industry (e.g., cloud computing, renewable energy, healthcare innovation) but where you believe the business fundamentals are real.
# >
# > ---
# >
# > ## 🔍 My recommendation for *you right now*
# >
# > Since you’re 21 and building up:
# >
# > * Most of your investment in your Fidelity Investments Roth IRA could go into broad-market index funds (as we discussed previously).
# > * Then, you could allocate a small portion (say **5–10%** of your total investment portfolio) to individual stocks you believe in and have researched thoroughly.
# > * Continue to learn about companies, industries, metrics, and keep a watchlist of maybe 3-5 stocks you’d like to own long-term.
# > * Review those stocks at least yearly and check if your investment thesis still holds.
# >
# > ---
# >
# > If you want, I can pull up **5-10 individual stocks** (with tickers) that many analysts are bullish on **right now**, and we can review whether each might fit your profile (age, risk tolerance, long-term horizon).
# > Would you like me to do that?

# %% [markdown]
# ### Thoughts
#
# I prefered Claude's responses more than ChatGPT's because they were more right to the point and helpful in my opinion. The ChatGPT responses have more information, but it does not feel as specific to what I was asking and all of the emojis make the experience a little overstimulating. I find it interesting that in the specific stocks prompt ChatGPT focused solely on education and did not show any specific stocks, while Claude did mention specific companies. Maybe OpenAI has stronger guardrails about not being sued than Anthropic. Overall, I found both responses helpful, but definitely prefered the format and clarity in Claude's responses.
